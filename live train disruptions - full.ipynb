// %% [markdown]
// ## Will you get to complain about Dutch trains this evening?

// %%
%use dataframe(v=0.13.1), kandy

// %% [markdown]
// Let's now try to get live json data using an http server endpoint.
//
// https://github.com/rijdendetreinen/gotrain
//
// I created a server using this repo from rijdendetreinen.nl and hosted it in the cloud. You can
// also build and host it locally.
//
// To know which API calls are available, we can look at [openapi.yaml](./openapi.yaml).

// %%
// (will be taken down)
val address = "http://34.141.147.240:8080"

// %%
val rawDf = DataFrame.read("$address/v2/status")
rawDf
// Out:
//             <iframe onload="o_resize_iframe_out_1()" style="width:100%;" class="result_container" id="iframe_out_1" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_-1241513984&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 1, columnsCount = 3&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &gt; 1) {

// %%
rawDf.schema()
// Out:
// arrivals: String
// departures: String
// services: String

// %% [markdown]
// This works! You can call any supported API (like JSON/CSV) and work with the data.
//
// However, types are only inferred. And that while the API offer strict types in the form of an OpenAPI spec with which Schema types you will get as a response.
//
// To enforce types, we can import the schemas from the OpenAPI spec and convert our DataFrame to it.

// %%
%trackExecution
val GoTrain = importDataSchema(
    "https://raw.githubusercontent.com/rijdendetreinen/gotrain/main/openapi.yaml"
)
// Out:
// Executing:
//
// val GoTrain = importDataSchema(
//     "https://raw.githubusercontent.com/rijdendetreinen/gotrain/main/openapi.yaml"
// )
//
// Executing:
// import org.jetbrains.kotlinx.dataframe.io.readJson
// import org.jetbrains.kotlinx.dataframe.io.readJsonStr
// import org.jetbrains.kotlinx.dataframe.api.convertTo
// import org.jetbrains.kotlinx.dataframe.api.first
// import org.jetbrains.kotlinx.dataframe.api.JsonPath
// import org.jetbrains.kotlinx.dataframe.api.DataSchemaEnum
// import org.jetbrains.kotlinx.dataframe.io.JSON.TypeClashTactic.*
// import org.jetbrains.kotlinx.dataframe.io.convertDataRowsWithOpenApi
// interface GoTrainDataSchema {
//
//     companion object {
//         val ApiVersion = GoTrainDataSchema.ApiVersion.Companion
//         val Arrival = GoTrainDataSchema.Arrival.Companion
//         val StationObject = GoTrainDataSchema.StationObject.Companion
//         val DepartureWing = GoTrainDataSchema.DepartureWing.Companion
//         val MaterialContent = GoTrainDataSchema.MaterialContent.Companion
//         val StopsContent = GoTrainDataSchema.StopsContent.Companion
//         val Departure = GoTrainDataSchema.Departure.Companion
//         val Service = GoTrainDataSchema.Service.Companion
//         val MaterialContent1 = GoTrainDataSchema.MaterialContent1.Companion
//         val StopsContent1 = GoTrainDataSchema.StopsContent1.Companion
//         val PartsContent = GoTrainDataSchema.PartsContent.Companion
//         val SystemStatus = GoTrainDataSchema.SystemStatus.Companion
//         val Statistics = GoTrainDataSchema.Statistics.Companion
//         val Counters = GoTrainDataSchema.Counters.Companion
//     }
//
//     @DataSchema(isOpen = false)
//     interface ApiVersion {
//         val version: kotlin.Int?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToApiVersion(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<ApiVersion>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<ApiVersion> = convertTo<ApiVersion> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<ApiVersion> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToApiVersion()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<ApiVersion> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToApiVersion()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<ApiVersion> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToApiVersion()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<ApiVersion> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToApiVersion()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface Arrival {
//         @ColumnName("arrival_time")
//         val arrivalTime: kotlinx.datetime.LocalDateTime?
//         val cancelled: kotlin.Boolean?
//         val company: kotlin.String?
//         val delay: kotlin.Int?
//         @ColumnName("origin_actual")
//         val originActual: kotlin.String?
//         @ColumnName("origin_actual_codes")
//         val originActualCodes: kotlin.collections.List<kotlin.String>?
//         @ColumnName("origin_planned")
//         val originPlanned: kotlin.String?
//         @ColumnName("platform_actual")
//         val platformActual: kotlin.String?
//         @ColumnName("platform_planned")
//         val platformPlanned: kotlin.String?
//         @ColumnName("platform_changed")
//         val platformChanged: kotlin.Boolean?
//         val remarks: kotlin.collections.List<kotlin.String>?
//         @ColumnName("service_date")
//         val serviceDate: kotlinx.datetime.LocalDate?
//         @ColumnName("service_id")
//         val serviceId: kotlin.String?
//         @ColumnName("service_number")
//         val serviceNumber: kotlin.String?
//         val station: kotlin.String?
//         val status: kotlin.Int?
//         val timestamp: kotlinx.datetime.LocalDateTime?
//         val type: kotlin.String?
//         @ColumnName("type_code")
//         val typeCode: kotlin.String?
//         val via: kotlin.String?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToArrival(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<Arrival>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<Arrival> = convertTo<Arrival> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<Arrival> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToArrival()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Arrival> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToArrival()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<Arrival> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToArrival()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Arrival> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToArrival()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface StationObject {
//         val code: kotlin.String?
//         val short: kotlin.String?
//         val medium: kotlin.String?
//         val long: kotlin.String?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToStationObject(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<StationObject>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<StationObject> = convertTo<StationObject> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<StationObject> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStationObject()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<StationObject> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStationObject()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<StationObject> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStationObject()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<StationObject> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStationObject()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface DepartureWing {
//         @ColumnName("destination_actual")
//         val destinationActual: GoTrainDataSchema.StationObject?
//         @ColumnName("destination_planned")
//         val destinationPlanned: GoTrainDataSchema.StationObject?
//         val material: org.jetbrains.kotlinx.dataframe.DataFrame<GoTrainDataSchema.MaterialContent?>
//         val remarks: kotlin.collections.List<kotlin.String>?
//         val stops: org.jetbrains.kotlinx.dataframe.DataFrame<GoTrainDataSchema.StopsContent?>
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToDepartureWing(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<DepartureWing>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<DepartureWing> = convertTo<DepartureWing> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<DepartureWing> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDepartureWing()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<DepartureWing> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDepartureWing()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<DepartureWing> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDepartureWing()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<DepartureWing> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDepartureWing()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface MaterialContent {
//         val accessible: kotlin.Boolean?
//         val destination: kotlin.String?
//         @ColumnName("destination_code")
//         val destinationCode: kotlin.String?
//         val number: kotlin.String?
//         @ColumnName("remains_behind")
//         val remainsBehind: kotlin.Boolean?
//         val type: kotlin.String?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToMaterialContent(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<MaterialContent>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent> = convertTo<MaterialContent> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface StopsContent {
//         val code: kotlin.String?
//         val short: kotlin.String?
//         val medium: kotlin.String?
//         val long: kotlin.String?
//         val accessible: kotlin.Boolean?
//         @ColumnName("arrival_cancelled")
//         val arrivalCancelled: kotlin.Boolean?
//         @ColumnName("arrival_delay")
//         val arrivalDelay: kotlin.Int?
//         @ColumnName("arrival_platform")
//         val arrivalPlatform: kotlin.String?
//         @ColumnName("arrival_platform_changed")
//         val arrivalPlatformChanged: kotlin.Boolean?
//         @ColumnName("arrival_time")
//         val arrivalTime: kotlinx.datetime.LocalDateTime?
//         @ColumnName("assistance_available")
//         val assistanceAvailable: kotlin.Any?
//         @ColumnName("departure_cancelled")
//         val departureCancelled: kotlin.Boolean?
//         @ColumnName("departure_delay")
//         val departureDelay: kotlin.Int?
//         @ColumnName("departure_platform")
//         val departurePlatform: kotlin.String?
//         @ColumnName("departure_platform_changed")
//         val departurePlatformChanged: kotlin.Boolean?
//         @ColumnName("departure_time")
//         val departureTime: kotlinx.datetime.LocalDateTime?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToStopsContent(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<StopsContent>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent> = convertTo<StopsContent> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface Departure {
//         val cancelled: kotlin.Boolean?
//         val company: kotlin.String?
//         val delay: kotlin.Int?
//         @ColumnName("departure_time")
//         val departureTime: kotlinx.datetime.LocalDateTime?
//         @ColumnName("destination_actual")
//         val destinationActual: kotlin.String?
//         @ColumnName("destination_actual_codes")
//         val destinationActualCodes: kotlin.collections.List<kotlin.String>?
//         @ColumnName("destination_planned")
//         val destinationPlanned: kotlin.String?
//         @ColumnName("platform_actual")
//         val platformActual: kotlin.String?
//         @ColumnName("platform_planned")
//         val platformPlanned: kotlin.String?
//         @ColumnName("platform_changed")
//         val platformChanged: kotlin.Boolean?
//         val remarks: kotlin.collections.List<kotlin.String>?
//         val tips: kotlin.collections.List<kotlin.String>?
//         @ColumnName("service_date")
//         val serviceDate: kotlinx.datetime.LocalDate?
//         @ColumnName("service_id")
//         val serviceId: kotlin.String?
//         @ColumnName("service_number")
//         val serviceNumber: kotlin.String?
//         val station: kotlin.String?
//         val status: kotlin.Int?
//         val timestamp: kotlinx.datetime.LocalDateTime?
//         val type: kotlin.String?
//         @ColumnName("type_code")
//         val typeCode: kotlin.String?
//         val via: kotlin.String?
//         val wings: org.jetbrains.kotlinx.dataframe.DataFrame<GoTrainDataSchema.DepartureWing?>
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToDeparture(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<Departure>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<Departure> = convertTo<Departure> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<Departure> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDeparture()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Departure> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDeparture()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<Departure> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDeparture()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Departure> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToDeparture()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface Service {
//         val company: kotlin.String?
//         val id: kotlin.String?
//         @ColumnName("journey_planner")
//         val journeyPlanner: kotlin.Boolean?
//         val parts: org.jetbrains.kotlinx.dataframe.DataFrame<GoTrainDataSchema.PartsContent?>
//         val remarks: kotlin.collections.List<kotlin.String>?
//         val tips: kotlin.collections.List<kotlin.String>?
//         @ColumnName("reservation_required")
//         val reservationRequired: kotlin.Boolean?
//         @ColumnName("with_supplement")
//         val withSupplement: kotlin.Boolean?
//         @ColumnName("service_date")
//         val serviceDate: kotlinx.datetime.LocalDate?
//         @ColumnName("service_number")
//         val serviceNumber: kotlin.String?
//         val timestamp: kotlinx.datetime.LocalDateTime?
//         val type: kotlin.String?
//         @ColumnName("type_code")
//         val typeCode: kotlin.String?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToService(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<Service>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<Service> = convertTo<Service> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<Service> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToService()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Service> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToService()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<Service> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToService()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Service> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToService()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface MaterialContent1 {
//         val accessible: kotlin.Boolean?
//         val destination: kotlin.String?
//         @ColumnName("destination_code")
//         val destinationCode: kotlin.String?
//         val number: kotlin.String?
//         val position: kotlin.Int?
//         @ColumnName("remains_behind")
//         val remainsBehind: kotlin.Boolean?
//         val type: kotlin.String?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToMaterialContent1(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<MaterialContent1>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent1> = convertTo<MaterialContent1> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent1()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent1()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent1()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<MaterialContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToMaterialContent1()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface StopsContent1 {
//         @ColumnName("arrival_cancelled")
//         val arrivalCancelled: kotlin.Boolean?
//         @ColumnName("arrival_delay")
//         val arrivalDelay: kotlin.Int?
//         @ColumnName("arrival_platform_actual")
//         val arrivalPlatformActual: kotlin.String?
//         @ColumnName("arrival_platform_planned")
//         val arrivalPlatformPlanned: kotlin.String?
//         @ColumnName("arrival_time")
//         val arrivalTime: kotlinx.datetime.LocalDateTime?
//         @ColumnName("assistance_available")
//         val assistanceAvailable: kotlin.Boolean?
//         @ColumnName("departure_cancelled")
//         val departureCancelled: kotlin.Boolean?
//         @ColumnName("departure_delay")
//         val departureDelay: kotlin.Int?
//         @ColumnName("departure_platform_actual")
//         val departurePlatformActual: kotlin.String?
//         @ColumnName("departure_platform_planned")
//         val departurePlatformPlanned: kotlin.String?
//         @ColumnName("departure_time")
//         val departureTime: kotlinx.datetime.LocalDateTime?
//         @ColumnName("do_not_board")
//         val doNotBoard: kotlin.Boolean?
//         val material: org.jetbrains.kotlinx.dataframe.DataFrame<GoTrainDataSchema.MaterialContent1?>
//         val remarks: kotlin.collections.List<kotlin.String>?
//         val station: GoTrainDataSchema.StationObject?
//         @ColumnName("station_accessible")
//         val stationAccessible: kotlin.Boolean?
//         @ColumnName("stop_type")
//         val stopType: kotlin.String?
//         @ColumnName("stopping_actual")
//         val stoppingActual: kotlin.Boolean?
//         @ColumnName("stopping_planned")
//         val stoppingPlanned: kotlin.Boolean?
//         val tips: kotlin.collections.List<kotlin.String>?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToStopsContent1(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<StopsContent1>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent1> = convertTo<StopsContent1> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent1()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent1()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent1()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<StopsContent1> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStopsContent1()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface PartsContent {
//         val remarks: kotlin.collections.List<kotlin.String>?
//         @ColumnName("service_number")
//         val serviceNumber: kotlin.String?
//         val stops: org.jetbrains.kotlinx.dataframe.DataFrame<GoTrainDataSchema.StopsContent1?>
//         val tips: kotlin.collections.List<kotlin.String>?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToPartsContent(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<PartsContent>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<PartsContent> = convertTo<PartsContent> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<PartsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToPartsContent()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<PartsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToPartsContent()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<PartsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToPartsContent()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<PartsContent> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToPartsContent()
//         }
//
//     }
//     enum class StatusField(override val value: kotlin.String) : org.jetbrains.kotlinx.dataframe.api.DataSchemaEnum {
//         UNKNOWN("UNKNOWN"),
//         DOWN("DOWN"),
//         RECOVERING("RECOVERING"),
//         UP("UP");
//     }
//     @DataSchema(isOpen = false)
//     interface SystemStatus {
//         val arrivals: GoTrainDataSchema.StatusField?
//         val departures: GoTrainDataSchema.StatusField?
//         val services: GoTrainDataSchema.StatusField?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToSystemStatus(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<SystemStatus>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<SystemStatus> = convertTo<SystemStatus> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<SystemStatus> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToSystemStatus()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<SystemStatus> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToSystemStatus()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<SystemStatus> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToSystemStatus()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<SystemStatus> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToSystemStatus()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface Statistics {
//         val counters: GoTrainDataSchema.Counters?
//         val inventory: kotlin.Int?
//         val status: GoTrainDataSchema.StatusField?
//         @ColumnName("last_status_change")
//         val lastStatusChange: kotlinx.datetime.LocalDateTime?
//         @ColumnName("average_messages")
//         val averageMessages: kotlin.Float?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToStatistics(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<Statistics>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<Statistics> = convertTo<Statistics> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<Statistics> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStatistics()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Statistics> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStatistics()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<Statistics> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStatistics()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Statistics> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToStatistics()
//         }
//
//     }
//     @DataSchema(isOpen = false)
//     interface Counters {
//         val received: kotlin.Int?
//         val processed: kotlin.Int?
//         val error: kotlin.Int?
//         val duplicate: kotlin.Int?
//         @ColumnName("too_late")
//         val tooLate: kotlin.Int?
//         public companion object {
//           public val keyValuePaths: kotlin.collections.List<org.jetbrains.kotlinx.dataframe.api.JsonPath>
//             get() = listOf()
//
//           public fun org.jetbrains.kotlinx.dataframe.DataFrame<*>.convertToCounters(convertTo: org.jetbrains.kotlinx.dataframe.api.ConvertSchemaDsl<Counters>.() -> kotlin.Unit = {}): org.jetbrains.kotlinx.dataframe.DataFrame<Counters> = convertTo<Counters> {
//               convertDataRowsWithOpenApi()
//               convertTo()
//           }
//
//           public fun readJson(url: java.net.URL): org.jetbrains.kotlinx.dataframe.DataFrame<Counters> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(url, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToCounters()
//
//           public fun readJson(path: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Counters> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(path, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToCounters()
//
//           public fun readJson(stream: java.io.InputStream): org.jetbrains.kotlinx.dataframe.DataFrame<Counters> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJson(stream, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToCounters()
//
//           public fun readJsonStr(text: kotlin.String): org.jetbrains.kotlinx.dataframe.DataFrame<Counters> = org.jetbrains.kotlinx.dataframe.DataFrame
//               .readJsonStr(text, typeClashTactic = ANY_COLUMNS, keyValuePaths = keyValuePaths)
//               .convertToCounters()
//         }
//
//     }
// }
//
//
// Executing:
// DISPLAY("Data schema successfully imported as GoTrain: GoTrainDataSchema")
// Data schema successfully imported as GoTrain: GoTrainDataSchema
// Executing:
// val GoTrain = GoTrainDataSchema

// %%
%trackExecution off

// %%
val status = 
    GoTrain.SystemStatus.readJson("$address/v2/status")
// or rawDf.convertToSystemStatus()

status
// Out:
//             <iframe onload="o_resize_iframe_out_2()" style="width:100%;" class="result_container" id="iframe_out_2" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_-1241513982&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 1, columnsCount = 3&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let left = leftBorder
//             let right = rightBorder
//             if (size &gt; 1) {

// %%
status.schema()
// Out:
// arrivals: Line_15_jupyter.GoTrainDataSchema.StatusField
// departures: Line_15_jupyter.GoTrainDataSchema.StatusField
// services: Line_15_jupyter.GoTrainDataSchema.StatusField

// %% [markdown]
// As you can see, we now have `StatusField` types instead of `String`!
//
// And since this is an enum, we can use it safely in an exhaustive when statement:

// %%
"arrivals server is " + when (status.first().arrivals) {
    GoTrainDataSchema.StatusField.UNKNOWN -> "unknown"
    GoTrainDataSchema.StatusField.DOWN -> "down"
    GoTrainDataSchema.StatusField.RECOVERING -> "recovering"
    GoTrainDataSchema.StatusField.UP -> "up"
    // exhaustive!
}
// Out:
// arrivals server is up

// %% [markdown]
// Now, in notebooks, that's about how useful these OpenAPI type schema's get, but
// if you're using DataFrame outside the magical world of notebooks, you can highly benefit of
// the generation of these type schemas.
//
// [Let's take a look!](src/main/kotlin/nl/jolanrensen/dataFrameAndNotebooks/Main.kt)

// %% [markdown]
// Let's explore the API a bit more. For which station would you like to see the departures?

// %%
// drag and drop
val stations202309 = DataFrame.readCSV("data/disruptions/stations-2023-09.csv", delimiter = ',')
stations202309
// Out:
//             <iframe onload="o_resize_iframe_out_3()" style="width:100%;" class="result_container" id="iframe_out_3" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_-1241513980&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;... showing only top 20 of 591 rows&lt;&sol;p&gt;&lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 591, columnsCount = 11&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let

// %%
import nl.jolanrensen.dataFrameAndNotebooks.getDeparturesForStation

//val stationCode = "ASD" // Amsterdam central
val stationCode = "BD" // Breda
//val stationCode = "UT" // Utrecht
//val stationCode = "TB" // Tilburg

val departures = getDeparturesForStation(stationCode, address)

departures
// Out:
// cancelled: Boolean
// company: String
// delay: Int
// departureTime: kotlinx.datetime.Instant
// destinationActual: String
// destinationActualCodes: List<String>
// destinationPlanned: String
// lineNumber: kotlinx.datetime.Instant?
// name: String?
// platformActual: String
// platformChanged: Boolean
// platformPlanned: String
// remarks: List<String>
// serviceDate: kotlinx.datetime.LocalDate
// serviceId: String
// serviceNumber: String
// station: String
// status: Int
// timestamp: kotlinx.datetime.Instant
// tips: List<String>
// type: String
// typeCode: String
// via: String
// wings: *
//     destination_actual:
//         code: String?
//         long: String?
//         medium: String?
//         short: String?
//     destination_planned:
//         code: String?
//         long: String?
//         medium: String?
//         short: String?
//     material: *
//         accessible: Boolean?
//         destination: String?
//         destination_code: String?
//         number: String?
//         remains_behind: Boolean?
//         type: String?
//     remarks: List<String>?
//     stops: *
//         accessible: Boolean?
//         arrival_cancelled: Boolean?
//         arrival_delay: Int?
//         arrival_platform: String?
//         arrival_platform_changed: Boolean?
//         arrival_time: kotlinx.datetime.LocalDateTime?
//         assistance_available: Any?
//         code: String?
//         departure_cancelled: Boolean?
//         departure_delay: Int?
//         departure_platform: String?
//         departure_platform_changed: Boolean?
//         departure_time: kotlinx.datetime.LocalDateTime?
//         long: String?
//         medium: String?
//         short: String?
//
// destinationAndType: String
// departureTimeWithDelay: kotlinx.datetime.Instant
//             <iframe onload="o_resize_iframe_out_9()" style="width:100%;" class="result_container" id="iframe_out_9" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: &quot;Helvetica Neue&quot;, Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody &gt; tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody &gt; tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody &gt; tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover &gt; td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// &sol;* formatting *&sol;
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
// :root {
//     --scroll-bg: #f5f5f5;
//     --scroll-fg: #b3b3b3;
// }
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;]{
//     --scroll-bg: #3c3c3c;
//     --scroll-fg: #97e1fb;
// }
// body {
//     scrollbar-color: var(--scroll-fg) var(--scroll-bg);
// }
// body::-webkit-scrollbar {
//     width: 10px; &sol;* Mostly for vertical scrollbars *&sol;
//     height: 10px; &sol;* Mostly for horizontal scrollbars *&sol;
// }
// body::-webkit-scrollbar-thumb {
//     background-color: var(--scroll-fg);
// }
// body::-webkit-scrollbar-track {
//     background-color: var(--scroll-bg);
// }
//             &lt;&sol;style&gt;
//         &lt;&sol;head&gt;
//         &lt;body&gt;
//             &lt;table class=&quot;dataframe&quot; id=&quot;df_-1241513928&quot;&gt;&lt;&sol;table&gt;
//
// &lt;p class=&quot;dataframe_description&quot;&gt;... showing only top 20 of 22 rows&lt;&sol;p&gt;&lt;p class=&quot;dataframe_description&quot;&gt;DataFrame: rowsCount = 22, columnsCount = 26&lt;&sol;p&gt;
//
//         &lt;&sol;body&gt;
//         &lt;script&gt;
//             (function () {
//     window.DataFrame = window.DataFrame || new (function () {
//         this.addTable = function (df) {
//             let cols = df.cols;
//             for (let i = 0; i &lt; cols.length; i++) {
//                 for (let c of cols[i].children) {
//                     cols[c].parent = i;
//                 }
//             }
//             df.nrow = 0
//             for (let i = 0; i &lt; df.cols.length; i++) {
//                 if (df.cols[i].values.length &gt; df.nrow) df.nrow = df.cols[i].values.length
//             }
//             if (df.id === df.rootId) {
//                 df.expandedFrames = new Set()
//                 df.childFrames = {}
//                 const table = this.getTableElement(df.id)
//                 table.df = df
//                 for (let i = 0; i &lt; df.cols.length; i++) {
//                     let col = df.cols[i]
//                     if (col.parent === undefined &amp;&amp; col.children.length &gt; 0) col.expanded = true
//                 }
//             } else {
//                 const rootDf = this.getTableData(df.rootId)
//                 rootDf.childFrames[df.id] = df
//             }
//         }
//
//         this.computeRenderData = function (df) {
//             let result = []
//             let pos = 0
//             for (let col = 0; col &lt; df.cols.length; col++) {
//                 if (df.cols[col].parent === undefined)
//                     pos += this.computeRenderDataRec(df.cols, col, pos, 0, result, false, false)
//             }
//             for (let i = 0; i &lt; result.length; i++) {
//                 let row = result[i]
//                 for (let j = 0; j &lt; row.length; j++) {
//                     let cell = row[j]
//                     if (j === 0)
//                         cell.leftBd = false
//                     if (j &lt; row.length - 1) {
//                         let nextData = row[j + 1]
//                         if (nextData.leftBd) cell.rightBd = true
//                         else if (cell.rightBd) nextData.leftBd = true
//                     } else cell.rightBd = false
//                 }
//             }
//             return result
//         }
//
//         this.computeRenderDataRec = function (cols, colId, pos, depth, result, leftBorder, rightBorder) {
//             if (result.length === depth) {
//                 const array = [];
//                 if (pos &gt; 0) {
//                     let j = 0
//                     for (let i = 0; j &lt; pos; i++) {
//                         let c = result[depth - 1][i]
//                         j += c.span
//                         let copy = Object.assign({empty: true}, c)
//                         array.push(copy)
//                     }
//                 }
//                 result.push(array)
//             }
//             const col = cols[colId];
//             let size = 0;
//             if (col.expanded) {
//                 let childPos = pos
//                 for (let i = 0; i &lt; col.children.length; i++) {
//                     let child = col.children[i]
//                     let childLeft = i === 0 &amp;&amp; (col.children.length &gt; 1 || leftBorder)
//                     let childRight = i === col.children.length - 1 &amp;&amp; (col.children.length &gt; 1 || rightBorder)
//                     let childSize = this.computeRenderDataRec(cols, child, childPos, depth + 1, result, childLeft, childRight)
//                     childPos += childSize
//                     size += childSize
//                 }
//             } else {
//                 for (let i = depth + 1; i &lt; result.length; i++)
//                     result[i].push({id: colId, span: 1, leftBd: leftBorder, rightBd: rightBorder, empty: true})
//                 size = 1
//             }
//             let l

// %%
import nl.jolanrensen.dataFrameAndNotebooks.currentTimeInAmsterdam
import nl.jolanrensen.dataFrameAndNotebooks.setToNullsWhere


val showActualOnly = false
departures
//    .filter { delay == 0 }
//    .filter { platformChanged }
    .plot {

        // defines the order of the platforms
        val platforms = buildSet {
            addAll(platformActual.values)
            addAll(platformPlanned.values)
        }
            .sortedBy { it.filter { it.isLetter() } }
            .sortedBy { it.filter { it.isDigit() }.toInt() }

        val time = currentTimeInAmsterdam()

        // defines all times scale (will be categorical for tiles)
        val times = buildSet {
            addAll(departureTime.values)
            addAll(departureTimeWithDelay.values)
            add(time)
        }.sorted()

        // defines the x-axis scale
        x {
            scale = categorical(platforms)
        }

        // defines the y-axis scale
        y {
            scale = categorical(times)
            axis.breaks(format = "%H:%M")
        }

        // actual train departures + delays
        tiles {
            x(platformActual)
            y(departureTimeWithDelay)
            width = 0.5
            height = 0.9
            fillColor(destinationAndType)

            borderLine {
                width = 0.5
                color = Color.BLACK
            }
        }

        // showing planned trains translucent
        if (!showActualOnly) tiles {
            x(platformPlanned)
            y(departureTime)
            width = 0.5
            height = 0.9
            fillColor(destinationAndType)
            alpha = 0.3
        }

        // showing a line between planned trains and actual departures
        if (!showActualOnly) segments {
            xBegin(platformPlanned)
            yBegin(departureTime)
            xEnd(platformActual)
            yEnd(departureTimeWithDelay)

            color(destinationPlanned) {
                legend.type = LegendType.None
            }
            alpha = 0.6
            lineType = LineType.DASHED
        }

        // showing a X through canceled trains
        points {
            x(platformActual.setToNullsWhere(!cancelled))
            y(departureTimeWithDelay)
            color = Color.RED
            size = 15.0
            symbol = Symbol.CROSS
        }

        // a dashed line for the current time
        line {
            x(platformPlanned)
            y(platformActual.map { time })
            type = LineType.DOTTED
        }

        layout {
            size = 1000 to 800
            xAxisLabel = "Platform"
            yAxisLabel = "Departure time"
        }
    }
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='1000' height='800' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.2.0/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;jAXRbA&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//        var plotSpec={
// &quot;mapping&quot;:{
// },
// &quot;data&quot;:{
// &quot;departureTimeWithDelay&quot;:[1.7135397E12,1.71354E12,1.71354018E12,1.71354018E12,1.71354036E12,1.71354108E12,1.71354114E12,1.71354132E12,1.7135415E12,1.7135415E12,1.7135418E12,1.71354198E12,1.71354198E12,1.71354288E12,1.71354294E12,1.7135433E12,1.7135436E12,1.71354378E12,1.71354378E12,1.71354396E12,1.71354468E12,1.71354474E12],
// &quot;departureTime&quot;:[1.7135397E12,1.71354E12,1.71354018E12,1.71354018E12,1.71354036E12,1.71354108E12,1.71354114E12,1.71354132E12,1.7135415E12,1.7135415E12,1.7135418E12,1.71354198E12,1.71354198E12,1.71354288E12,1.71354294E12,1.7135433E12,1.7135436E12,1.71354378E12,1.71354378E12,1.71354396E12,1.71354468E12,1.71354474E12],
// &quot;platformActual&quot;:[&quot;8&quot;,&quot;3&quot;,&quot;4&quot;,&quot;6&quot;,&quot;5&quot;,&quot;3&quot;,&quot;6&quot;,&quot;5&quot;,&quot;7&quot;,&quot;8&quot;,&quot;3&quot;,&quot;6&quot;,&quot;7&quot;,&quot;3&quot;,&quot;7&quot;,&quot;8&quot;,&quot;3&quot;,&quot;6&quot;,&quot;7&quot;,&quot;5&quot;,&quot;3&quot;,&quot;6&quot;],
// &quot;destinationPlanned&quot;:[&quot;Roosendaal&quot;,&quot;Zwolle&quot;,&quot;Arnhem Centraal&quot;,&quot;Den Haag Centraal&quot;,&quot;Amsterdam Centraal&quot;,&quot;Eindhoven Centraal&quot;,&quot;Dordrecht&quot;,&quot;Brussel-Zuid Midi&quot;,&quot;Amsterdam Centraal&quot;,&quot;Roosendaal&quot;,&quot;Zwolle&quot;,&quot;Arnhem Centraal&quot;,&quot;Den Haag Centraal&quot;,&quot;Eindhoven Centraal&quot;,&quot;Dordrecht&quot;,&quot;Roosendaal&quot;,&quot;Zwolle&quot;,&quot;Arnhem Centraal&quot;,&quot;Den Haag Centraal&quot;,&quot;Amsterdam Centraal&quot;,&quot;Eindhoven Centraal&quot;,&quot;Dordrecht&quot;],
// &quot;platformActual**&quot;:[1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12,1.713543135508E12],
// &quot;destinationAndType&quot;:[&quot;Roosendaal (Intercity)&quot;,&quot;Zwolle (Intercity)&quot;,&quot;Arnhem Centraal (Sprinter)&quot;,&quot;Den Haag Centraal (Intercity)&quot;,&quot;Amsterdam Centraal (Intercity direct)&quot;,&quot;Eindhoven Centraal (Intercity)&quot;,&quot;Dordrecht (Sprinter)&quot;,&quot;Brussel-Zuid Midi (Intercity direct)&quot;,&quot;Amsterdam Centraal (Intercity direct)&quot;,&quot;Roosendaal (Intercity)&quot;,&quot;Zwolle (Intercity)&quot;,&quot;Arnhem Centraal (Sprinter)&quot;,&quot;Den Haag Centraal (Intercity)&quot;,&quot;Eindhoven Centraal (Intercity)&quot;,&quot;Dordrecht (Sprinter)&quot;,&quot;Roosendaal (Intercity)&quot;,&quot;Zwolle (Intercity)&quot;,&quot;Arnhem Centraal (Sprinter)&quot;,&quot;Den Haag Centraal (Intercity)&quot;,&quot;Amsterdam Centraal (Intercity direct)&quot;,&quot;Eindhoven Centraal (Intercity)&quot;,&quot;Dordrecht (Sprinter)&quot;],
// &quot;platformActual*&quot;:[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],
// &quot;platformPlanned&quot;:[&quot;8&quot;,&quot;3&quot;,&quot;6&quot;,&quot;7&quot;,&quot;5&quot;,&quot;3&quot;,&quot;6&quot;,&quot;7&quot;,&quot;5&quot;,&quot;8&quot;,&quot;3&quot;,&quot;5&quot;,&quot;7&quot;,&quot;3&quot;,&quot;7&quot;,&quot;8&quot;,&quot;3&quot;,&quot;6&quot;,&quot;7&quot;,&quot;5&quot;,&quot;3&quot;,&quot;6&quot;]
// },
// &quot;ggsize&quot;:{
// &quot;width&quot;:1000.0,
// &quot;height&quot;:800.0
// },
// &quot;kind&quot;:&quot;plot&quot;,
// &quot;scales&quot;:[{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;fill&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;color&quot;,
// &quot;discrete&quot;:true,
// &quot;guide&quot;:&quot;none&quot;
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;datetime&quot;:true,
// &quot;limits&quot;:[null,null]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;discrete&quot;:true,
// &quot;limits&quot;:[&quot;3&quot;,&quot;4&quot;,&quot;5&quot;,&quot;6&quot;,&quot;7&quot;,&quot;8&quot;]
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;discrete&quot;:true,
// &quot;format&quot;:&quot;%H:%M&quot;,
// &quot;limits&quot;:[1713539700000,1713540000000,1713540180000,1713540360000,1713541080000,1713541140000,1713541320000,1713541500000,1713541800000,1713541980000,1713542880000,1713542940000,1713543135508,1713543300000,1713543600000,1713543780000,1713543960000,1713544680000,1713544740000]
// },{
// &quot;aesthetic&quot;:&quot;x&quot;,
// &quot;name&quot;:&quot;Platform&quot;
// },{
// &quot;aesthetic&quot;:&quot;y&quot;,
// &quot;name&quot;:&quot;Departure time&quot;
// }],
// &quot;layers&quot;:[{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;platformActual&quot;,
// &quot;y&quot;:&quot;departureTimeWithDelay&quot;,
// &quot;fill&quot;:&quot;destinationAndType&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;size&quot;:0.5,
// &quot;color&quot;:&quot;#000000&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;width&quot;:0.5,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;tile&quot;,
// &quot;height&quot;:0.9,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;platformPlanned&quot;,
// &quot;y&quot;:&quot;departureTime&quot;,
// &quot;fill&quot;:&quot;destinationAndType&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.3,
// &quot;width&quot;:0.5,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;tile&quot;,
// &quot;height&quot;:0.9,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;platformPlanned&quot;,
// &quot;y&quot;:&quot;departureTime&quot;,
// &quot;xend&quot;:&quot;platformActual&quot;,
// &quot;yend&quot;:&quot;departureTimeWithDelay&quot;,
// &quot;color&quot;:&quot;destinationPlanned&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;linetype&quot;:&quot;dashed&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;alpha&quot;:0.6,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;segment&quot;,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;platformActual*&quot;,
// &quot;y&quot;:&quot;departureTimeWithDelay&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;color&quot;:&quot;#ee6666&quot;,
// &quot;size&quot;:15.0,
// &quot;shape&quot;:4.0,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;point&quot;,
// &quot;data&quot;:{
// }
// },{
// &quot;mapping&quot;:{
// &quot;x&quot;:&quot;platformPlanned&quot;,
// &quot;y&quot;:&quot;platformActual**&quot;
// },
// &quot;stat&quot;:&quot;identity&quot;,
// &quot;linetype&quot;:&quot;dotted&quot;,
// &quot;sampling&quot;:&quot;none&quot;,
// &quot;position&quot;:&quot;identity&quot;,
// &quot;geom&quot;:&quot;line&quot;,
// &quot;

// %% [markdown]
// # Thank you for listening!

// %% [markdown]
// ## Check out the project on GitHub:

// %%
import java.net.URLEncoder

val url = URLEncoder.encode("https://github.com/Jolanrensen/DataFrameAndNotebooksAmsterdam2024", "UTF-8")

IMG(
    src = "https://api.qrserver.com/v1/create-qr-code/?size=150x150&data=$url",
    width = 300,
    height = 300,
)
// Out:
// <img src="https://api.qrserver.com/v1/create-qr-code/?size=150x150&data=https%3A%2F%2Fgithub.com%2FJolanrensen%2FDataFrameAndNotebooksAmsterdam2024" style="width:300px;height:300px;"}/>
